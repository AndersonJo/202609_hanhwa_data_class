# %%
from helper import load_titanic
import pandas as pd
df = load_titanic()
small = df[['Name', 'Age', 'Fare', 'Cabin']]
small.head(3)
# Out:
#                                                 Name   Age     Fare Cabin
# 0                            Braund, Mr. Owen Harris  22.0   7.2500   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833   C85
# 2                             Heikkinen, Miss. Laina  26.0   7.9250   NaN

# %%
styled = (small.style.format({'Fare': '{:,.1f}', 'Age': '{:.0f}'})
             .bar(subset=['Fare'], align='mid', color=['#ef9a9a', '#90caf9']))
styled
# Out:
# <style type="text/css">
# ...
